# %% [markdown]
# ## Ejercicio
#
# Grafiquen la nulclina para un circuito donde $x$ y $y$ se regulan mutuamente de forma negativa, y para uno donde $x$ reprime a $y$ pero $y$ activa a $x$.
#
# ### Preguntas:
#
# Qué sucede si no hay cooperatividad?
#
# Qué configuraciones se comportan como ``toggle`` (tienen dos estados estables)?

# %% [markdown]
# Cuando $x$ y $y$ se regulan mutuamente de forma negativa, tenemos:
# \begin{align}
# \frac{dx}{dt} = \beta_x\frac{1}{1 + (\frac{y}{k})^n} - \gamma_x x = 0
# \end{align}
# Encontramos el estado estable:
# \begin{align}
# x_{st} = \frac{\beta_x}{\gamma_x (1 + \frac{y}{k}^n)}
# \end{align}
# De la misma forma para $y$:
# \begin{align}
# y_{st} = \frac{\beta_y}{\gamma_y (1 + \frac{x}{k}^n)}
# \end{align}

# %%
y = np.linspace(0, 50, 1000)
x_rep = beta_x / (gamma*(1 + (y/k)**n))
plt.plot(y,x_rep, 'b-', x_rep, y, 'r-')
plt.xlabel('$x$')
plt.ylabel('$y$')
plt.margins(x=0.05, y=0.05)
plt.legend([r'$\frac{dy}{dt}=0$', r'$\frac{dx}{dt}=0$'], fontsize=20, loc=1)

# %% [markdown]
# Cuando $x$ reprime a $y$, pero $y$ activa a $x$, tenemos una combinación de las ecuaciones previas:
# \begin{align}
# x_{st} = \frac{\beta_x y^n}{\gamma_x (k^n + y^n)}
# \end{align}
# \begin{align}
# y_{st} = \frac{\beta_y}{\gamma_y (1 + \frac{x}{k}^n)}
# \end{align}

# %%
plt.plot(y,x_rep, 'b-', x_act, y, 'r-')
plt.xlabel('$x$')
plt.ylabel('$y$')
plt.margins(x=0.05, y=0.05)
plt.legend([r'$\frac{dy}{dt}=0$', r'$\frac{dx}{dt}=0$'], fontsize=20, loc=1)
